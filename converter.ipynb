# %%
import math
from transformers import pipeline
import speech_recognition as sr 
import os 
from pydub import AudioSegment
from pydub.silence import split_on_silence
from os import path
from pydub import AudioSegment


class Transcription():
    
    def convert_mp3_to_wav(self, src, dst):
        print('Converting started')
        sound = AudioSegment.from_mp3(src)
        sound.export(dst, format="wav")
        print('Converting ended')


    # a function that splits the audio file into chunks
    # and applies speech recognition
    def get_large_audio_transcription(self, path):
        """
        Splitting the large audio file into chunks
        and apply speech recognition on each of these chunks
        """
        print('Transcription started')
        # create a speech recognition object
        r = sr.Recognizer()

        # open the audio file using pydub
        sound = AudioSegment.from_wav(path)  
        # split audio sound where silence is 700 miliseconds or more and get chunks
        chunks = split_on_silence(sound,
            # experiment with this value for your target audio file
            min_silence_len = 700,
            # adjust this per requirement
            silence_thresh = sound.dBFS-14,
            # keep the silence for 1 second, adjustable as well
            keep_silence=500,
        )
        folder_name = "audio-chunks"
        # create a directory to store the audio chunks
        if not os.path.isdir(folder_name):
            os.mkdir(folder_name)
        whole_text = ""
        # process each chunk 
        for i, audio_chunk in enumerate(chunks, start=1):
            # export audio chunk and save it in
            # the `folder_name` directory.
            chunk_filename = os.path.join(folder_name, f"chunk{i}.wav")
            audio_chunk.export(chunk_filename, format="wav")
            # recognize the chunk
            with sr.AudioFile(chunk_filename) as source:
                audio_listened = r.record(source)
                # try converting it to text
                try:
                    text = r.recognize_google(audio_listened)
                except sr.UnknownValueError as e:
                    print("Error:", str(e))
                else:
                    text = f"{text.capitalize()}. "
                    print(f'sentence {i}', ":", text)
                    whole_text += text
        # return the text for all chunks detected
        print('Transcription end')
        return whole_text


    def make_summarization(self, whole_text: str) -> str:
        print('Summarization started')
        print('Length whole text: ', len(whole_text))
        summarizer = pipeline("summarization")

        pic = len(whole_text) / 4000
        pic = int(math.ceil(pic))

        summary = ""

        for i in range(0, int(pic)):
            border = len(whole_text) / int(pic)
            increment_i = i+1
            print(border*i, border*increment_i)

            curr_article = whole_text[int(border*i): int(border*increment_i)]
            curr_summary = summarizer(curr_article, max_length=130, min_length=30,
                                    do_sample=False)
            summary = summary + list(curr_summary[0].values())[0]


        print('Summarization ended')
        return summary


    def save_all(self, summary, whole_text):
        print('Saving started')
        with open("Output.txt", "w") as text_file:
            text_file.write("Summary:\n")
            text_file.write(summary)
            text_file.write("\n\n")
            text_file.write("Text:\n")
            text_file.write(whole_text)
        print('Saving ended')

# %%
def main():
    src = "sample.mp3"
    path = "sample.wav"

    trans = Transcription()
    
    trans.convert_mp3_to_wav(src, path)
    whole_text = trans.get_large_audio_transcription(path)
    summary = trans.make_summarization(whole_text)

    trans.save_all(summary, whole_text)

# %%
if __name__ == "__main__":
    main()
# Out:
# Converting started
# Converting ended
# Transcription started
# sentence 1 : From voa learning english this is science in the news i'm gene simmons.
# sentence 2 : Our program today is about a mystery as all this time.
# sentence 3 : Bob doherty and sarah long tell about the mystery of time.
# Error:
# sentence 5 : If you can read a clock you can know the time of day.
# sentence 6 : But no one knows what time itself is.
# sentence 7 : We cannot see it.
# sentence 8 : We cannot touch it.
# sentence 9 : We cannot hear it.
# sentence 10 : We know it only by the way we markets passing.
# sentence 11 : For all our success in measuring the smallest parts of time.
# sentence 12 : Time remains one of the great mysteries of the universe.
# sentence 13 : One way to think about time is to imagine a world without time.
# sentence 14 : There could be no movement.
# sentence 15 : Because time and movement cannot be separated.
# sentence 16 : A world without time could exist only as long as there were no changes.
# sentence 17 : 4 time and change are linked.
# sentence 18 : We know that time has passed.
# sentence 19 : When something changes.
# sentence 20 : In the real world the world with time.
# sentence 21 : Changes never stop.
# sentence 22 : Some changes happen only once in a while like an eclipse of the moon.
# sentence 23 : Others happen repeatedly.
# sentence 24 : Like the rising and setting of the sun.
# sentence 25 : Humans always have noted natural events that repeat themselves.
# sentence 26 : When people began to count such events.
# sentence 27 : They began to measure time.
# sentence 28 : In early human history.
# sentence 29 : The only changes that seem to repeat themselves evenly were the movements of objects in the sky.
# sentence 30 : The most easily seen result of these movements.
# sentence 31 : What's the difference between light.
# sentence 32 : And dark.
# sentence 33 : The sun rises in the eastern sky producing light.
# sentence 34 : It moves across the sky and sinks in the west.
# sentence 35 : Causing.
# sentence 36 : The appearance and disappearance of the sun was even and unfeeling.
# sentence 37 : The periods of light and darkness it created.
# sentence 38 : Were the first accepted periods of time.
# sentence 39 : We have named each period of light and darkness.
# sentence 40 : One day.
# sentence 41 : People saw the sun rise higher in the sky during the summer than in winter.
# sentence 42 : They counted the days that passed from the sun's highest position until it returned to that position.
# sentence 43 : They counted 365 days.
# sentence 44 : We now know that is the time birthday cakes to move once around the sun.
# sentence 45 : We call this period of time.
# sentence 46 : A year.
# sentence 47 : Early humans also noted changes in the moon.
# sentence 48 : Hazard moved across the night sky they must have wondered.
# sentence 49 : Why did it look different every night.
# sentence 50 : Why did it disappear.
# sentence 51 : Where did it go.
# sentence 52 : Even before they learn the answers to these questions.
# sentence 53 : They developed a way to use the changing faces of the moon.
# sentence 54 : To tell time.
# sentence 55 : The moon was full when it's face was bright and round.
# sentence 56 : The early humans counted the number of times the sun appeared between full moon.
# sentence 57 : They learnt that this number always remained the same.
# sentence 58 : About 29 sons.
# sentence 59 : 29 tonnes equals.
# sentence 60 : One moon.
# sentence 61 : We now know this period of time as 1-month.
# sentence 62 : Early humans hunted animals and gathered wild plants.
# sentence 63 : They moved in groups or tribes from place to place in search of food.
# sentence 64 : Then people learned to plant seeds and grow crops.
# sentence 65 : They learned to use animals to help them work.
# sentence 66 : And for food.
# sentence 67 : They found they no longer needed to move from one place to another to survive.
# sentence 68 : As hunters.
# sentence 69 : People did not need a way to measure time.
# sentence 70 : As farmers howell.
# sentence 71 : They had to plant crops in time to harvest them before winter.
# sentence 72 : They had to know when the seasons would change.
# sentence 73 : So they developed calendars.
# sentence 74 : No one knows when the first calendar was developed.
# sentence 75 : But it seems possible that it was based on moons or lunar month.
# sentence 76 : When people started farming.
# sentence 77 : The wise men of the tribes became very important.
# sentence 78 : They studied the sky.
# sentence 79 : They gathered enough information so they could know when the seasons would change.
# sentence 80 : They announced when it was time to play at craps.
# Error:
# sentence 82 : The divisions of time we used today were developed in ancient babylonia 4000 years ago.
# sentence 83 : Babylonian astronomers believe the sun moved around the earth.
# sentence 84 : Every 365 days.
# sentence 85 : They divided the trip into 12 equal parts.
# sentence 86 : 4 months.
# sentence 87 : Each month was 30 days.
# sentence 88 : Then they divided each day into 24 equal parts.
# sentence 89 : Or h.
# sentence 90 : They divided each hour into 60 minutes.
# sentence 91 : And each may.
# sentence 92 : Into 60 sex.
# sentence 93 : Humans have used many devices to measure time.
# sentence 94 : The sundial was one of the earliest and simplest.
# sentence 95 : A sundial measures the movement of the sun across the sky each day.
# sentence 96 : It has a stick or other object that rises above a flat surface.
# sentence 97 : The stig blocking sunlight.
# sentence 98 : Create a shadow.
# sentence 99 : As the sun moves so does the shadow of the stick across the flat surface.
# sentence 100 : Marks on the surface show the passing of hours and perhaps minute.
# sentence 101 : The sundial works well only when the sun is shining.
# sentence 102 : So other ways were invented to measure the passing of time.
# sentence 103 : One device is the hourglass.
# sentence 104 : It uses of thin stream of falling sand to measure time.
# sentence 105 : The hourglass is shaped like the number 8.
# sentence 106 : Wide at the top and bottom.
# sentence 107 : But very thin in the middle.
# sentence 108 : In a true hourglass it takes exactly one hour.
# sentence 109 : For all the sound to drop from the top.
# sentence 110 : To the bottom.
# sentence 111 : Through a very small open.
# sentence 112 : In the middle.
# sentence 113 : When the hourglass is turned with the upside down.
# sentence 114 : It begins to mark the passing of another hour.
# sentence 115 : By the 18th century.
# sentence 116 : People have developed mechanical clocks and watches.
# sentence 117 : And today many of our clocks and watches.
# sentence 118 : Are electronic.
# sentence 119 : So we have devices to mark the passing of time.
# sentence 120 : But what time is it now.
# sentence 121 : Clarks in different parts of the world do not show the same time at the same time.
# sentence 122 : This is because time on earth is set by the sun's position in the sky above.
# sentence 123 : We all have a 12:00 noon each day.
# sentence 124 : 12:00 is the time the sun is highest in the sky.
# sentence 125 : But when it is 12 noon where i am.
# sentence 126 : It may be 10:00 at night where you are.
# sentence 127 : As international communications and travel increase.
# sentence 128 : It became clear that it would be necessary to establish a common time for all parts of the.
# sentence 129 : In 1884.
# sentence 130 : An international conference divided the world into 24 time areas or zones.
# sentence 131 : Each zone represents one hour.
# sentence 132 : The astronomical observatory in greenwich england was chosen as the starting point for the time zone.
# sentence 133 : 12 zones are west of greenwich.
# sentence 134 : 12 rs.
# sentence 135 : The time at greenwich as measured by the sun.
# sentence 136 : Is cold.
# sentence 137 : Universal time.
# sentence 138 : For many years it was called greenwich mean time.
# sentence 139 : Some scientists say time is governed by the movement of matter in our universe.
# sentence 140 : They say time flows forward because the universe is expanding.
# sentence 141 : Some say it will stop expanding someday.
# sentence 142 : And will be going to move in the opposite direction.
# sentence 143 : To grow smaller.
# sentence 144 : Some believe time will also begin to flow in the opposite direction.
# sentence 145 : From the future to the past.
# sentence 146 : Can time move backwards.
# sentence 147 : Most people have no trouble agreeing the time moves forward.
# sentence 148 : We see people born and then grow old.
# sentence 149 : We remember the past.
# sentence 150 : But we do not know the future.
# sentence 151 : We know a film is moving forward if it shows a glass falling off a table and breaking into many pieces.
# sentence 152 : Is the film were moving backwards.
# sentence 153 : The pieces would rejoin to form a glass and jump back up onto the table.
# sentence 154 : No one has ever seen this happen except in a film.
# sentence 155 : Some scientists believe there is one reason why time only moves forward.
# sentence 156 : It is a well-known scientific law.
# sentence 157 : The second law of thermodynamics.
# sentence 158 : That lawyer says disorder increases with time.
# sentence 159 : In fact there are more conditions of the sword.
# sentence 160 : Then of order.
# sentence 161 : For example.
# sentence 162 : There are many ways a glass can break into pieces.
# sentence 163 : That is disorder.
# sentence 164 : But there is only one way the broken pieces can be organised to make a glass.
# sentence 165 : Bad is order.
# sentence 166 : If time moved back.
# sentence 167 : The broken pieces could come together in a great many ways.
# sentence 168 : Only one of these many ways however would reform the glass.
# sentence 169 : It is almost impossible to believe this would.
# sentence 170 : Not all scientists believe time is governed by the second law of thermodynamics.
# sentence 171 : They do not agree that time must always move forward.
# sentence 172 : The debate will continue about the nature of time.
# sentence 173 : And time will remain a mystery our program was written by marilyn cristiano and read by sarah long and bob geordie.
# sentence 174 : I'm june sims join us again next week for more news about science and the voice of america.
# Transcription end
# Summarization started
# Length whole text:  7602
# 0.0 3801.0
# /Applications/anaconda3/envs/python37/lib/python3.7/site-packages/transformers/modeling_utils.py:1432: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   beam_id = beam_token_id // vocab_size
# 3801.0 7602.0
# Summarization ended
# Saving started
# Saving ended
